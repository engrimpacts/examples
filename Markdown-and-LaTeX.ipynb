# %% [markdown]
# # Top Heading
# ## Smaller Heading
# Type some text in here.
#
# # Equations can be typeset using $\LaTeX$
#
# $\int_0^\infty = x^2 \frac{y}{5} dx$
#
# $\int_z^k f(x) dx = \sum\limits_{n=1}^N \left(\frac{x^2}{x^y}\right)$
