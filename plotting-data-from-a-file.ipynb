# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt(open('data_1.csv'), delimiter=',',skiprows=8, usecols=[0,1])
print(data)
# Out:
# [[ 0.        0.204035]
#  [ 0.0005    0.193417]
#  [ 0.001     0.182996]
#  ...,
#  [ 0.4985   -0.212901]
#  [ 0.499    -0.221901]
#  [ 0.4995   -0.229644]]

# %% [markdown]
# Note that in the previous output, the x data starts at 0, goes to 10, and contains 50 numbers.

# %%
plt.plot(data[:,0],data[:,1],'r');
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (g)')
plt.title('Sine Wave')
